# %%
import numpy as np

import matplotlib.pyplot as plt 

from keras.layers import Conv2D, Input, Dense, Dropout, MaxPool2D, UpSampling2D
from keras.models import Model
from keras.datasets import mnist, cifar10

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
(train, _), (test, _) = mnist.load_data()

# scaling input data
train = train.reshape([-1,28,28,1]) / 255
test = test.reshape([-1,28,28,1]) / 255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
# Adding noise to data
noise = 0.3
train_noise = train + noise * np.random.normal(0, 1, size=train.shape)
test_noise = test + noise * np.random.normal(0, 1, size=test.shape)

train_noise = np.clip(train_noise, 0, 1)
test_noise = np.clip(test_noise, 0, 1)

# %%
# sample noisy image

rows = 5 # defining no. of rows in figure
cols = 6 # defining no. of colums in figure
subplot_size = 2

f = plt.figure(figsize=(subplot_size*cols,subplot_size*rows)) # defining a figure 

for i in range(rows*cols): 
    f.add_subplot(rows,cols,i+1) # adding sub plot to figure on each iteration
    plt.imshow(train_noise[i].reshape([28,28]),cmap="Reds") 
    plt.axis("off")
plt.savefig("digits_noise.png")

# %%
# sample original image

rows = 5 # defining no. of rows in figure
cols = 6 # defining no. of colums in figure
subplot_size = 2
f = plt.figure(figsize=(subplot_size*cols, subplot_size*rows)) # defining a figure 

for i in range(rows*cols): 
    f.add_subplot(rows,cols,i+1) # adding sub plot to figure on each iteration
    plt.imshow(train[i].reshape([28,28]),cmap="Reds") 
    plt.axis("off")
plt.savefig("digits_original.png")

# %%
# Encoder 
inputs = Input(shape=(28,28,1))

x = Conv2D(32, 3, activation='relu', padding='same')(inputs)
x = MaxPool2D()(x)
x = Dropout(0.3)(x)
x = Conv2D(32, 3, activation='relu', padding='same')(x)
encoded = MaxPool2D()(x)

# %%
# Decoder

x = Conv2D(32, 3, activation='relu', padding='same')(encoded)
x = UpSampling2D()(x)
x = Dropout(0.3)(x)
x = Conv2D(32, 3, activation='relu', padding='same')(x)
x = UpSampling2D()(x)
decoded = Conv2D(1, 3, activation='sigmoid', padding='same')(x)

# %%
autoencoder = Model(inputs, decoded)
autoencoder.compile(optimizer='rmsprop', loss='binary_crossentropy')

autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
batch_size = 256

history = autoencoder.fit(train_noise,
                train,
                epochs=epochs,
                batch_size=batch_size,
                shuffle=True,
                validation_data=(test_noise, test)
               )
# Out:
# Epoch 1/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1923 - val_loss: 0.1145
# Epoch 2/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1169 - val_loss: 0.0981
# Epoch 3/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1053 - val_loss: 0.0943
# Epoch 4/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0996 - val_loss: 0.0905
# Epoch 5/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0963 - val_loss: 0.0865
# Epoch 6/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0941 - val_loss: 0.0867
# Epoch 7/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0925 - val_loss: 0.0866
# Epoch 8/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0913 - val_loss: 0.0858
# Epoch 9/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0904 - val_loss: 0.0845
# Epoch 10/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0896 - val_loss: 0.0834
# Epoch 11/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0890 - val_loss: 0.0823
# Epoch 12/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0886 - val_loss: 0.0824
# Epoch 13/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0881 - val_loss: 0.0819
# Epoch 14/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0877 - val_loss: 0.0855
# Epoch 15/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0874 - val_loss: 0.0815
# Epoch 16/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0871 - val_loss: 0.0822
# Epoch 17/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0869 - val_loss: 0.0806
# Epoch 18/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0866 - val_loss: 0.0822
# Epoch 19/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0864 - val_loss: 0.0812
# Epoch 20/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0862 - val_loss: 0.0806
# Epoch 21/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0860 - val_loss: 0.0802
# Epoch 22/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0859 - val_loss: 0.0813
# Epoch 23/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0857 - val_loss: 0.0808
# Epoch 24/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0856 - val_loss: 0.0813
# Epoch 25/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0855 - val_loss: 0.0801
# Epoch 26/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0854 - val_loss: 0.0799
# Epoch 27/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0852 - val_loss: 0.0803
# Epoch 28/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0851 - val_loss: 0.0806
# Epoch 29/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0850 - val_loss: 0.0806
# Epoch 30/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0850 - val_loss: 0.0799
# Epoch 31/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0849 - val_loss: 0.0795
# Epoch 32/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0848 - val_loss: 0.0805
# Epoch 33/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0847 - val_loss: 0.0803
# Epoch 34/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0847 - val_loss: 0.0798
# Epoch 35/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0846 - val_loss: 0.0800
# Epoch 36/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0845 - val_loss: 0.0802
# Epoch 37/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0845 - val_loss: 0.0793
# Epoch 38/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0844 - val_loss: 0.0801
# Epoch 39/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0843 - val_loss: 0.0794
# Epoch 40/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0843 - val_loss: 0.0801
# Epoch 41/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0842 - val_loss: 0.0797
# Epoch 42/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0842 - val_loss: 0.0795
# Epoch 43/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0842 - val_loss: 0.0797
# Epoch 44/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0841 - val_loss: 0.0806
# Epoch 45/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0841 - val_loss: 0.0790
# Epoch 46/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0840 - val_loss: 0.0799
# Epoch 47/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0840 - val_loss: 0.0792
# Epoch 48/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0840 - val_loss: 0.0787
# Epoch 49/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0839 - val_loss: 0.0792
# Epoch 50/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0839 - val_loss: 0.0789

# %%
# Select few random test images
num_imgs = 16
rand = np.random.randint(1, 100)

test_images = test_noise[rand:rand+num_imgs] # slicing
test_desoided = autoencoder.predict(test_images) # predict

# %%
# Visualize test images with their denoised images

rows = 2 # defining no. of rows in figure
cols = 8 # defining no. of colums in figure

f = plt.figure(figsize=(2*cols,2*rows*2)) # defining a figure 

for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows*2,cols, (2*i*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(test_images[i*cols + j].reshape([28,28]),cmap="Reds") 
        plt.axis("off")
        
    for j in range(cols): 
        f.add_subplot(rows*2,cols,((2*i+1)*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(test_desoided[i*cols + j].reshape([28,28]),cmap="Reds") 
        plt.axis("off")
        
f.suptitle("Autoencoder Results",fontsize=18)
plt.savefig("test_results.png")

plt.show()
